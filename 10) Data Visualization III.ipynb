# %%
# !pip install pandas matplotlib seaborn

# %%
# Step 1: Import all required libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Step 2: Load the Iris dataset from local CSV file (downloaded beforehand)

data = pd.read_csv(r'C:\Users\LOQ\Downloads\archive\iris.data.csv', header=None)
data.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# Display the first 5 rows
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Print column names
print(data.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
# Step: List features and their types
print("Features and their types:")
print("sepal_length, sepal_width, petal_length, petal_width: Numeric")
print("species: Nominal")
# Out:
# Features and their types:
# sepal_length, sepal_width, petal_length, petal_width: Numeric
# species: Nominal

# %%
# Step : Create histograms for each feature
data.hist(figsize=(10, 8))
plt.suptitle("Histograms of Features")
plt.show()
